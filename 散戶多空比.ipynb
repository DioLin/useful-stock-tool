# %%
import requests
import pandas as pd
from io import StringIO
import time
import re
import datetime

session = requests.Session()

commodity_id="MXF"
#取得當天日期並轉換
today=datetime.date.today()
#print(today)
queryDate=str(today).replace("-","/")

#queryDate="2020/03/23"
print(queryDate)

paramsPost = {"commodity_id":"MTX","queryDate":queryDate,"dateaddcnt":"-1","commodity_idt":"MTX","marketCode":"0","commodity_id2":"","commodity_id2t2":"","MarketCode":"0","queryType":"2","commodity_id2t":""}
headers = {"Origin":"https://www.taifex.com.tw","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8","Upgrade-Insecure-Requests":"1","User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:72.0) Gecko/20100101 Firefox/72.0","Connection":"close","Referer":"https://www.taifex.com.tw/cht/3/futDailyMarketReport","Accept-Language":"zh-TW,zh;q=0.8,en-US;q=0.5,en;q=0.3","Accept-Encoding":"gzip, deflate","Content-Type":"application/x-www-form-urlencoded"}
cookies = {"BIGipServerPOOL_WWW_TCP_80":"471208108.20480.0000","BIGipServerPOOL_iRule_WWW_Group":"404099244.20480.0000","ROUTEID":".tomcat3","_ga":"GA1.3.2004033134.1582683667","JSESSIONID":"FAC0D51834C7549C500FBAECA6F77301.tomcat3","BIGipServerPOOL_iRule_WWW_ts50search":"420876460.20480.0000","_gid":"GA1.3.1451304631.1582683667"}
response = session.post("https://www.taifex.com.tw/cht/3/futDailyMarketReport", data=paramsPost, headers=headers, cookies=cookies)

#print("Status code:   %i" % response.status_code)
#print("Response body: %s" % response.content)

response.encoding = 'UTF-8'
dfs = pd.read_html(StringIO(response.text), encoding='UTF-8')
df=dfs[2].drop([0,1,2])
dff=df.iloc[:10,1:13]
dff
# Out:
# 2020/03/31
#           1     2     3     4      5    6       7           8           9   \
# 3   到期月份(週別)   開盤價   最高價   最低價  最後成交價  漲跌價     漲跌%  *盤後交易時段成交量  *一般交易時段成交量
# 4   202004W1  9758  9794  9587   9680  ▲24  ▲0.25%         334        1190
# 5     202004  9662  9718  9495   9596  ▲30  ▲0.31%      133747      209386
# 6     202005  9598  9650  9429   9530  ▲30  ▲0.32%        2180        3566
# 7     202006  9525  9575  9361   9455  ▲24  ▲0.25%         390         602
# 8     202009  9145  9182  8975   9064  ▲25  ▲0.28%          96         180
# 9     202012  9040  9080  8870   8973  ▲30  ▲0.34%          61         145
# 10    202103  8958  9000  8800   8880  ▲40  ▲0.45%          48          95
# 11       NaN   NaN   NaN   NaN    NaN  NaN     小計:      136856      215164
# 12       NaN   NaN   NaN   NaN    NaN  NaN     NaN         NaN         NaN
#
#         10    11       12
# 3   *合計成交量   結算價  *未沖銷契約量
# 4     1524  9679     1061
# 5   343133  9595    32159
# 6     5746  9529     5993
# 7      992  9455     2558
# 8      276  9065     1234
# 9      206  8963     1347
# 10     143  8870      303
# 11  352020   NaN    44655
# 12     NaN   NaN      NaN

# %%
def postfunc(id,Date):
    session2 = requests.Session()
    paramsPost2 = {"queryDate":Date,"dateaddcnt":"","doQuery":"1","goDay":"","commodityId":id,"queryType":"1"}
    headers2 = {"Origin":"https://www.taifex.com.tw","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8","Upgrade-Insecure-Requests":"1","User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:72.0) Gecko/20100101 Firefox/72.0","Connection":"close","Referer":"https://www.taifex.com.tw/cht/3/futContractsDate","Accept-Language":"zh-TW,zh;q=0.8,en-US;q=0.5,en;q=0.3","Accept-Encoding":"gzip, deflate","Content-Type":"application/x-www-form-urlencoded"}
    cookies2 = {"BIGipServerPOOL_WWW_TCP_80":"471208108.20480.0000","c":"8c936b59dc569b26b816019ca2cb19f01709a701350","BIGipServerPOOL_iRule_WWW_Group":"404099244.20480.0000","ROUTEID":".tomcat3","_gat":"1","_ga":"GA1.3.2004033134.1582683667","JSESSIONID":"B80A16FA099F41D49840B4C1B5937B5C.tomcat3","BIGipServerPOOL_iRule_WWW_ts50search":"420876460.20480.0000","_gid":"GA1.3.285759117.1583137315"}
    response2 = session2.post("https://www.taifex.com.tw/cht/3/futContractsDate", data=paramsPost2, headers=headers2, cookies=cookies2)
    #print("Status code:   %i" % response2.status_code)
    #print("Response body: %s" % response2.content)
    return response2

# %%
'''
session2 = requests.Session()
paramsPost2 = {"queryDate":queryDate,"dateaddcnt":"","doQuery":"1","goDay":"","commodityId":"MXF","queryType":"1"}
headers2 = {"Origin":"https://www.taifex.com.tw","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8","Upgrade-Insecure-Requests":"1","User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:72.0) Gecko/20100101 Firefox/72.0","Connection":"close","Referer":"https://www.taifex.com.tw/cht/3/futContractsDate","Accept-Language":"zh-TW,zh;q=0.8,en-US;q=0.5,en;q=0.3","Accept-Encoding":"gzip, deflate","Content-Type":"application/x-www-form-urlencoded"}
cookies2 = {"BIGipServerPOOL_WWW_TCP_80":"471208108.20480.0000","c":"8c936b59dc569b26b816019ca2cb19f01709a701350","BIGipServerPOOL_iRule_WWW_Group":"404099244.20480.0000","ROUTEID":".tomcat3","_gat":"1","_ga":"GA1.3.2004033134.1582683667","JSESSIONID":"B80A16FA099F41D49840B4C1B5937B5C.tomcat3","BIGipServerPOOL_iRule_WWW_ts50search":"420876460.20480.0000","_gid":"GA1.3.285759117.1583137315"}
response2 = session2.post("https://www.taifex.com.tw/cht/3/futContractsDate", data=paramsPost2, headers=headers2, cookies=cookies2)
'''
response4=postfunc("MXF",queryDate)
response4.encoding = 'UTF-8'
dfs2 = pd.read_html(StringIO(response4.text), encoding='UTF-8')
df2=dfs2[2].drop([0,1])
df2.iloc[:8,0:13]
# Out:
#      0          1         2        3         4        5        6       7   \
# 2   NaN  交易口數與契約金額     未平倉餘額      NaN       NaN      NaN      NaN     NaN
# 3    多方         空方      多空淨額       多方        空方     多空淨額      NaN     NaN
# 4    序號       商品名稱       身份別       口數      契約金額       口數     契約金額      口數
# 5     1     小型臺指期貨       自營商    15912   7615614    14383  6885206    1529
# 6    投信          0         0        0         0        0        0      82
# 7    外資     133346  63869140   132201  63321754     1145   547386    4573
# 8  期貨小計        自營商     15912  7615614     14383  6885206     1529  730408
# 9    投信          0         0        0         0        0        0      82
#
#         8        9        10       11       12
# 2      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN
# 4     契約金額       口數     契約金額       口數     契約金額
# 5   730408    11595  5541992    12709  6027547
# 6    39340        0        0       82    39340
# 7  2193408     3173  1522049     1400   671359
# 8    11595  5541992    12709  6027547    -1114
# 9    39340        0        0       82    39340

# %%
"""
散戶多單=全市場未平倉量-三大法人多單
散戶空單=全市場未平倉量-三大法人空單
散戶多空比=(散戶多單-散戶空單)/全市場未平倉*100%
"""

totalpointer=3 #刪掉3列所以從第3列開始起算，找到小計所在的列數，決定當天的所有期貨"到期月份" 總數

while True:
    #print(dff[7][totalpointer])
    totalpointer=totalpointer+1
    if dff[7][totalpointer] =="小計:" : break
     
print("小台指期當日未沖銷契約量=",int(dff[12][totalpointer]))
print("未到期留倉量=",(int(dff[12][totalpointer])-int(dff[12][4])))
print("==================")
print("自營多單=",int(df2[9][5]))
print("投信多單=",int(df2[7][6]))
print("外資多單=",int(df2[7][7]))
print("==================")
print("自營空單=",int(df2[11][5]))
print("投信空單=",int(df2[9][6]))
print("外資空單=",int(df2[9][7]))
print("==================")

#print(dff[12][totalpointer])
indiviualPlayer_long=int(dff[12][totalpointer])-int(dff[12][4])-(int(df2[9][5])+int(df2[7][6])+int(df2[7][7]))
indiviualPlayer_short=int(dff[12][totalpointer])-int(dff[12][4])-(int(df2[11][5])+int(df2[9][6])+int(df2[9][7]))
print("散戶多單=",indiviualPlayer_long)
print("散戶空單=",indiviualPlayer_short)
print(queryDate+"散戶多空比="+'%.2f%%' %(100*(indiviualPlayer_long-indiviualPlayer_short)/(int(dff[12][totalpointer])-int(dff[12][4]))))
# Out:
# 小台指期當日未沖銷契約量= 44655
# 未到期留倉量= 43594
# ==================
# 自營多單= 11595
# 投信多單= 82
# 外資多單= 4573
# ==================
# 自營空單= 12709
# 投信空單= 0
# 外資空單= 3173
# ==================
# 散戶多單= 27344
# 散戶空單= 27712
# 2020/03/31散戶多空比=-0.84%

# %%
#大戶指標

session3 = requests.Session()

paramsPost3 = {"contractId":"all","datecount":"","queryDate":queryDate,"contractId2":"all"}
headers3 = {"Origin":"https://www.taifex.com.tw","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8","Upgrade-Insecure-Requests":"1","User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:72.0) Gecko/20100101 Firefox/72.0","Connection":"close","Referer":"https://www.taifex.com.tw/cht/3/largeTraderFutQry","Accept-Language":"zh-TW,zh;q=0.8,en-US;q=0.5,en;q=0.3","Accept-Encoding":"gzip, deflate","Content-Type":"application/x-www-form-urlencoded"}
cookies3 = {"BIGipServerPOOL_WWW_TCP_80":"471208108.20480.0000","BIGipServerPOOL_iRule_WWW_Group":"404099244.20480.0000","ROUTEID":".tomcat3","_ga":"GA1.3.2004033134.1582683667","JSESSIONID":"E515C7A02E89026F7F36A4134AFD6FEB.tomcat3","BIGipServerPOOL_iRule_WWW_ts50search":"420876460.20480.0000","_gid":"GA1.3.285759117.1583137315"}
response3 = session3.post("https://www.taifex.com.tw/cht/3/largeTraderFutQry", data=paramsPost3, headers=headers3, cookies=cookies3)

#print("Status code:   %i" % response3.status_code)
#print("Response body: %s" % response3.content)
response3.encoding = 'UTF-8'
dfs3 = pd.read_html(StringIO(response3.text), encoding='UTF-8')
df3=dfs3[2].drop([0,1])
df3.iloc[:7,0:10]
# Out:
#                    0                  1                  2                  3  \
# 2               契約名稱           到期月份(週別)                 買方                 賣方
# 3  前五大交易人合計 (特定法人合計)  前十大交易人合計 (特定法人合計)  前五大交易人合計 (特定法人合計)  前十大交易人合計 (特定法人合計)
# 4                部位數                百分比                部位數                百分比
# 5     臺股期貨(TX+MTX/4)         202004  W1           215  (0)        81.1%  (0%)
# 6           2020  04   31,045  (31,045)     34.7%  (34.7%)   51,566  (48,700)
# 7               所有契約   35,745  (29,279)     33.7%  (27.6%)   60,864  (54,398)
# 8               電子期貨           2020  04     1,638  (1,638)     70.9%  (70.9%)
#
#                 4                 5             6                 7  \
# 2       全市場未沖銷部位數               NaN           NaN               NaN
# 3             NaN               NaN           NaN               NaN
# 4             部位數               百分比           部位數               百分比
# 5        241  (0)       90.9%  (0%)      217  (0)       81.9%  (0%)
# 6  57.7%  (54.5%)  42,105  (34,850)  47.1%  (39%)  50,225  (41,162)
# 7  57.4%  (51.3%)  47,236  (36,050)  44.5%  (34%)  57,172  (39,543)
# 8  1,887  (1,800)    81.7%  (77.9%)  1,302  (482)    56.4%  (20.9%)
#
#                 8               9
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
# 5        232  (0)     87.5%  (0%)
# 6    56.2%  (46%)           89431
# 7  53.9%  (37.3%)          106095
# 8    1,744  (625)  75.5%  (27.1%)

# %%
"""大戶指標 大戶多空比 ＝（多方十大交易人佔比 － 空方十大交易人佔比）－ 多空分界點"""
#print(df3[4][7])
biglong=re.split('[()%]',df3[4][7])
#print(biglong)
bigsell=re.split('[()%]',df3[8][7])
print(queryDate+"大戶多空比="+'%.2f%%' %(float(biglong[0])-float(bigsell[0])))
# Out:
# 2020/03/31大戶多空比=3.50%

# %%
response5=postfunc("TXF",queryDate)
response5.encoding = 'UTF-8'
dfs5 = pd.read_html(StringIO(response5.text), encoding='UTF-8')
df5=dfs5[2].drop([0,1])
df5.iloc[:8,0:13]
# Out:
#      0          1          2         3          4         5         6   \
# 2   NaN  交易口數與契約金額      未平倉餘額       NaN        NaN       NaN       NaN
# 3    多方         空方       多空淨額        多方         空方      多空淨額       NaN
# 4    序號       商品名稱        身份別        口數       契約金額        口數      契約金額
# 5     1       臺股期貨        自營商     13780   26415968     14504  27798236
# 6    投信         87     167083       105     201230       -18    -34146
# 7    外資      88421  169464946     87480  167693375       941   1771571
# 8  期貨小計        自營商      13780  26415968      14504  27798236      -724
# 9    投信         87     167083       105     201230       -18    -34146
#
#          7          8         9         10        11         12
# 2       NaN        NaN       NaN       NaN       NaN        NaN
# 3       NaN        NaN       NaN       NaN       NaN        NaN
# 4        口數       契約金額        口數      契約金額        口數       契約金額
# 5      -724   -1382269     19979  38047531     16644   31630862
# 6      4103    7873657     36395  69840949    -32292  -61967292
# 7     63320  121454735     15245  29189681     48075   92265054
# 8  -1382269      19979  38047531     16644  31630862       3335
# 9      4103    7873657     36395  69840949    -32292  -61967292

# %%
print(queryDate+"小台散戶多單=",indiviualPlayer_long)
print(queryDate+"小台散戶空單=",indiviualPlayer_short)
print(queryDate+"小台散戶多空比="+'%.2f%%' %(100*(indiviualPlayer_long-indiviualPlayer_short)/(int(dff[12][totalpointer])-int(dff[12][4]))))
print(queryDate+"大台外資多單=",df5[11][7])
print(queryDate+"大戶多空比="+'%.2f%%' %(float(biglong[0])-float(bigsell[0])))
# Out:
# 2020/03/31小台散戶多單= 27344
# 2020/03/31小台散戶空單= 27712
# 2020/03/31小台散戶多空比=-0.84%
# 2020/03/31大台外資多單= 48075
# 2020/03/31大戶多空比=3.50%
